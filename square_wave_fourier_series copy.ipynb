# %% [markdown]
# Import the required packages.

# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
L = 2
m = 1000
x = np.linspace(0, 2*L, m)
#Generate Square Wave
Y = []
for n in x:
    if n <= L:
        y = 1
    else:
        y = -1
    Y.append(y)
#Add fourier components
for n in range(3,200,10):
    print(n, 'Fourier components.')
    #n = 30 # choose the number of Fourier Components to add
    sum = np.zeros(m)
    for i in range(1, n, 2):
        sin = np.sin(i*math.pi*x/L)/i
        sum = sin + sum  
    sum = 4*sum/math.pi
    sns.set(font_scale= 2)
    sns.set_style('whitegrid')
    plt.figure(figsize= (15,7))
    sns.lineplot(x = x, y = sum, linewidth = 5)
    sns.lineplot(x = x, y = Y, color = 'red')
    plt.xlabel('x')
    plt.ylabel('y');
# Out:
# 3 Fourier components.
# 13 Fourier components.
# 23 Fourier components.
# 33 Fourier components.
# 43 Fourier components.
# 53 Fourier components.
# 63 Fourier components.
# 73 Fourier components.
# 83 Fourier components.
# 93 Fourier components.
# 103 Fourier components.
# 113 Fourier components.
# 123 Fourier components.
# 133 Fourier components.
# 143 Fourier components.
# 153 Fourier components.
# 163 Fourier components.
# 173 Fourier components.
# 183 Fourier components.
# 193 Fourier components.
